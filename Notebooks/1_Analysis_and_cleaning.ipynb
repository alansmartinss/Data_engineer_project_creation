# %%
# %pip install numpy
# %pip install pandas
# %pip install matplotlib
# %pip install seaborn
# Out:
# ...
#
# ...
#
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    ----------- ---------------------------- 2.4/8.0 MB 11.2 MB/s eta 0:00:01
#    ---------------------- ----------------- 4.5/8.0 MB 11.2 MB/s eta 0:00:01
#    -------------------------------- ------- 6.6/8.0 MB 10.9 MB/s eta 0:00:01
#    ---------------------------------------- 8.0/8.0 MB 10.4 MB/s eta 0:00:00
# ...
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# ...
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 2.2/2.2 MB 11.3 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    ----------------------------------- ---- 2.4/2.6 MB 11.2 MB/s eta 0:00:01
#    ---------------------------------------- 2.6/2.6 MB 10.8 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
import sys
sys.path.append(r"C:\Users\ALAN\Documents\GitHub\Data_engineer_project_creation")
from created_functions.data_cleaning import drop_rows_with_excessive_missing, impute_missing_values
from created_functions.basic_analysys import *

# %%
file_path = "../Datasets/heart_disease.csv"
data = pd.read_csv(file_path)
data.head()
# Out:
#     Age  Gender  Blood Pressure  Cholesterol Level Exercise Habits Smoking  \
# 0  56.0    Male           153.0              155.0            High     Yes
# 1  69.0  Female           146.0              286.0            High      No
# 2  46.0    Male           126.0              216.0             Low      No
# 3  32.0  Female           122.0              293.0            High     Yes
# 4  60.0    Male           166.0              242.0             Low     Yes
#
#   Family Heart Disease Diabetes        BMI High Blood Pressure  ...  \
# 0                  Yes       No  24.991591                 Yes  ...
# 1                  Yes      Yes  25.221799                  No  ...
# 2                   No       No  29.855447                  No  ...
# 3                  Yes       No  24.130477                 Yes  ...
# 4                  Yes      Yes  20.486289                 Yes  ...
#
#   High LDL Cholesterol Alcohol Consumption Stress Level Sleep Hours  \
# ...

# %% [markdown]
# # Basic Data Analysys

# %% [markdown]
# ## Display general dataset information

# %%
display_dataset_info(data)
# Out:
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Age                   9971 non-null   float64
#  1   Gender                9981 non-null   object
#  2   Blood Pressure        9981 non-null   float64
#  3   Cholesterol Level     9970 non-null   float64
#  4   Exercise Habits       9975 non-null   object
#  5   Smoking               9975 non-null   object
#  6   Family Heart Disease  9979 non-null   object
#  7   Diabetes              9970 non-null   object
#  8   BMI                   9978 non-null   float64
#  9   High Blood Pressure   9974 non-null   object
#  10  Low HDL Cholesterol   9975 non-null   object
#  11  High LDL Cholesterol  9974 non-null   object
#  12  Alcohol Consumption   7414 non-null   object
#  13  Stress Level          9978 non-null   object
# ...

# %% [markdown]
# ## Check for missing values

# %%
display_missing_values(data)
# Out:
# Missing Values by Column:
# Age                       29
# Gender                    19
# Blood Pressure            19
# Cholesterol Level         30
# Exercise Habits           25
# Smoking                   25
# Family Heart Disease      21
# Diabetes                  30
# BMI                       22
# High Blood Pressure       26
# Low HDL Cholesterol       25
# High LDL Cholesterol      26
# Alcohol Consumption     2586
# Stress Level              22
# Sleep Hours               25
# Sugar Consumption         30
# Triglyceride Level        26
# Fasting Blood Sugar       22
# CRP Level                 26
# Homocysteine Level        20
# Heart Disease Status       0
# dtype: int64

# %% [markdown]
# ## View the percentage of missing values

# %%
display_missing_percentage(data)
# Out:
# Percentage of Missing Values by Column:
# Age                      0.29
# Gender                   0.19
# Blood Pressure           0.19
# Cholesterol Level        0.30
# Exercise Habits          0.25
# Smoking                  0.25
# Family Heart Disease     0.21
# Diabetes                 0.30
# BMI                      0.22
# High Blood Pressure      0.26
# Low HDL Cholesterol      0.25
# High LDL Cholesterol     0.26
# Alcohol Consumption     25.86
# Stress Level             0.22
# Sleep Hours              0.25
# Sugar Consumption        0.30
# Triglyceride Level       0.26
# Fasting Blood Sugar      0.22
# CRP Level                0.26
# Homocysteine Level       0.20
# Heart Disease Status     0.00
# dtype: float64

# %% [markdown]
# ## Analyze the distribution of numerical features

# %%
display_numerical_analysis(data)
# Out:
# Statistical Analysis of Numerical Features:
#                Age  Blood Pressure  Cholesterol Level          BMI  \
# count  9971.000000     9981.000000        9970.000000  9978.000000
# mean     49.296259      149.757740         225.425577    29.077269
# std      18.193970       17.572969          43.575809     6.307098
# min      18.000000      120.000000         150.000000    18.002837
# 25%      34.000000      134.000000         187.000000    23.658075
# 50%      49.000000      150.000000         226.000000    29.079492
# 75%      65.000000      165.000000         263.000000    34.520015
# max      80.000000      180.000000         300.000000    39.996954
#
#        Sleep Hours  Triglyceride Level  Fasting Blood Sugar    CRP Level  \
# count  9975.000000         9974.000000          9978.000000  9974.000000
# mean      6.991329          250.734409           120.142213     7.472201
# std       1.753195           87.067226            23.584011     4.340248
# ...

# %% [markdown]
# ## Boxplots to check for outliers in numerical features

# %%
plot_numerical_boxplots(data)

# %% [markdown]
# ## Histogram to check distribution

# %%
plot_numerical_distributions(data)

# %% [markdown]
# ## Categorical feature analysis

# %%
display_categorical_analysis(data)
# Out:
# Frequency Analysis of Categorical Features:
#
# Gender - Unique Values and Frequencies:
# Gender
# Male      5003
# Female    4978
# Name: count, dtype: int64
#
# Exercise Habits - Unique Values and Frequencies:
# Exercise Habits
# High      3372
# Medium    3332
# Low       3271
# Name: count, dtype: int64
#
# Smoking - Unique Values and Frequencies:
# Smoking
# Yes    5123
# No     4852
# Name: count, dtype: int64
#
# Family Heart Disease - Unique Values and Frequencies:
# Family Heart Disease
# No     5004
# Yes    4975
# Name: count, dtype: int64
#
# Diabetes - Unique Values and Frequencies:
# Diabetes
# No     5018
# Yes    4952
# Name: count, dtype: int64
#
# High Blood Pressure - Unique Values and Frequencies:
# High Blood Pressure
# Yes    5022
# No     4952
# Name: count, dtype: int64
#
# Low HDL Cholesterol - Unique Values and Frequencies:
# Low HDL Cholesterol
# Yes    5000
# No     4975
# Name: count, dtype: int64
#
# High LDL Cholesterol - Unique Values and Frequencies:
# ...

# %% [markdown]
# ## Visualization of categorical features

# %%
plot_categorical_distributions(data)

# %% [markdown]
# ## Correlation between numerical features

# %%
plot_correlation_matrix(data)
# Out:
# Correlation between Numerical Features:

# %% [markdown]
# ## Check target variable balance (Heart Disease Status)

# %%
target_col = 'Heart Disease Status'
analyze_target_variable(data, target_col)
# Out:
# Target Variable Distribution:
# Heart Disease Status
# No     8000
# Yes    2000
# Name: count, dtype: int64

# %% [markdown]
# # Simple adjustment of missing variables

# %%
data_cleaned = drop_rows_with_excessive_missing(data)

# %%
display_missing_percentage(data_cleaned)
# Out:
# Percentage of Missing Values by Column:
# Age                      0.29
# Gender                   0.19
# Blood Pressure           0.19
# Cholesterol Level        0.30
# Exercise Habits          0.25
# Smoking                  0.25
# Family Heart Disease     0.21
# Diabetes                 0.30
# BMI                      0.22
# High Blood Pressure      0.26
# Low HDL Cholesterol      0.25
# High LDL Cholesterol     0.26
# Alcohol Consumption     25.86
# Stress Level             0.22
# Sleep Hours              0.25
# Sugar Consumption        0.30
# Triglyceride Level       0.26
# Fasting Blood Sugar      0.22
# CRP Level                0.26
# Homocysteine Level       0.20
# Heart Disease Status     0.00
# dtype: float64

# %%
data_imputed = impute_missing_values(data_cleaned)

# %%
display_missing_percentage(data_imputed)
# Out:
# Percentage of Missing Values by Column:
# Age                     0.0
# Gender                  0.0
# Blood Pressure          0.0
# Cholesterol Level       0.0
# Exercise Habits         0.0
# Smoking                 0.0
# Family Heart Disease    0.0
# Diabetes                0.0
# BMI                     0.0
# High Blood Pressure     0.0
# Low HDL Cholesterol     0.0
# High LDL Cholesterol    0.0
# Alcohol Consumption     0.0
# Stress Level            0.0
# Sleep Hours             0.0
# Sugar Consumption       0.0
# Triglyceride Level      0.0
# Fasting Blood Sugar     0.0
# CRP Level               0.0
# Homocysteine Level      0.0
# Heart Disease Status    0.0
# dtype: float64

# %%
data_imputed
# Out:
#        Age  Gender  Blood Pressure  Cholesterol Level Exercise Habits Smoking  \
# 0     56.0    Male           153.0              155.0            High     Yes
# 1     69.0  Female           146.0              286.0            High      No
# 2     46.0    Male           126.0              216.0             Low      No
# 3     32.0  Female           122.0              293.0            High     Yes
# 4     60.0    Male           166.0              242.0             Low     Yes
# ...    ...     ...             ...                ...             ...     ...
# 9995  25.0  Female           136.0              243.0          Medium     Yes
# 9996  38.0    Male           172.0              154.0          Medium      No
# 9997  73.0    Male           152.0              201.0            High     Yes
# 9998  23.0    Male           142.0              299.0             Low     Yes
# 9999  38.0  Female           128.0              193.0          Medium     Yes
#
# ...

# %%
# Set the path to save the file
output_path = r"C:\Users\ALAN\Documents\GitHub\Data_engineer_project_creation\Datasets\adjusted_dataset.csv"
# Save the adjusted dataset in CSV format
data_imputed.to_csv(output_path, index=False)
print(f"Dataset successfully saved to: {output_path}")
# Out:
# Dataset successfully saved to: C:\Users\ALAN\Documents\GitHub\Data_engineer_project_creation\Datasets\adjusted_dataset.csv
